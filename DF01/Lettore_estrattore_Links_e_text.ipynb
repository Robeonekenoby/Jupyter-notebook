# %%
import csv
import selenium
import time
import pandas as pd
from selenium import webdriver

# %%
with open(r'C:\Users\robeo\Desktop\DataframeNova01.csv', 'r') as csv_file:   # r read legge il file csv
    csv_reader = csv.DictReader(csv_file)
    
    links = []
    
    for line in csv_reader:
        links.append(line.get('Link'))
print(links)
# Out:
# ['https://nova.ilsole24ore.com/infodata/il-covid-19-e-la-seconda-ondata-dellinfodemia-diffidate-di-chi-usa-i-numeri-assoluti/', 'https://nova.ilsole24ore.com/infodata/elezioni-usa-gli-effetti-della-sorpresa-di-ottobre/', 'https://nova.ilsole24ore.com/infodata/acqua-alta-a-venezia-tutti-gli-eventi-eccezionali-dal-1875-il-mose-funziona/', 'https://nova.ilsole24ore.com/infodata/come-si-misura-la-sostenibilita-di-un-investimento-green-e-digitale/', 'https://nova.ilsole24ore.com/infodata/il-reddito-di-base-universale-dal-1960-a-oggi-in-una-infografica/', 'https://nova.ilsole24ore.com/infodata/finals-nba-lakers-conducono-2-0-miami-ancora-ko/', 'https://nova.ilsole24ore.com/infodata/tre-quindicenni-su-quattro-dichiarano-di-essere-tutto-sommato-soddisfatti-della-propria-vita/', 'https://nova.ilsole24ore.com/infodata/tre-numeri-sul-fenomeno-dei-monopattini-elettrici-2/', 'https://nova.ilsole24ore.com/infodata/biodiversita-mancati-tutti-gli-obiettivi-ll-living-planet-index-spiegato-bene/', 'https://nova.ilsole24ore.com/infodata/cosa-accade-in-un-minuto-su-internet-le-novita-del-lockdown/', 'https://nova.ilsole24ore.com/infodata/biglietti-visitatore-e-digitale-come-si-misura-la-cultura-parliamo-di-musei/', 'https://nova.ilsole24ore.com/infodata/come-si-misura-la-vecchiaia-nel-tempo/', 'https://nova.ilsole24ore.com/infodata/come-si-misurano-i-musei-scopri-i-numeri-e-la-mappa-degli-itinerari/', 'https://nova.ilsole24ore.com/infodata/tre-numeri-sul-fenomeno-dei-monopattini-elettrici/', 'https://nova.ilsole24ore.com/infodata/biodiversita-cattive-notizie-il-25-delle-specie-animali-e-vegetali-a-rischio-estinzione-ll-living-planet-index-spiegato-bene/', 'https://nova.ilsole24ore.com/infodata/come-stanno-i-quindicenni-di-oggi-vivere-in-una-nazione-ricca-non-e-garanzia-di-maggior-felicita/', 'https://nova.ilsole24ore.com/infodata/cosa-accade-in-un-minuto-su-internet-un-grande-classico-le-novita-del-lockdown/', 'https://nova.ilsole24ore.com/infodata/finali-di-nba-los-angeles-lakers-contro-miami-heat-chi-vincera-le-previsioni/', 'https://nova.ilsole24ore.com/infodata/il-reddito-di-base-univerale-o-di-cittadinanza-dal-1960-a-oggi-in-una-infografica/', 'https://nova.ilsole24ore.com/infodata/scuola-scopri-quanto-sono-vecchi-gli-insegnanti-di-tuo-figlio/', 'https://nova.ilsole24ore.com/infodata/a-proposito-di-dati-cosi-google-maps-diventa-anche-mappa-dei-casi-di-coronavirus/', 'https://nova.ilsole24ore.com/infodata/elezioni-usa-ora-biden-e-favorito-in-attesa-dei-dibattiti-in-tv/', 'https://nova.ilsole24ore.com/infodata/quando-una-persona-puo-essere-definita-anziana%e2%80%89ecco-come-si-misura-la-vecchiaia-nel-tempo/', 'https://nova.ilsole24ore.com/infodata/a-proposito-di-dati-le-mappe-catastali-piu-aperte-e-accessibili-basta-citare-la-fonte-2/', 'https://nova.ilsole24ore.com/infodata/turismo-e-pandemia-che-fine-hanno-fatto-canadesi-russi-e-statunitensi/', 'https://nova.ilsole24ore.com/infodata/le-paure-nellera-post-pandemia-il-clima-ci-spaventa-almeno-quanto-il-covid-19/', 'https://nova.ilsole24ore.com/infodata/boom-di-notifiche-con-la-riapertura-della-scuola-i-nuovi-numeri-di-immuni/', 'https://nova.ilsole24ore.com/infodata/a-proposito-di-dati-dopo-trenta-giorni-google-drive-cancella-i-file-nel-cestino-2/', 'https://nova.ilsole24ore.com/infodata/regionali-il-pd-festeggia-dopo-le-elezioni-ecco-cosa-suggeriscono-i-numeri/', 'https://nova.ilsole24ore.com/infodata/fiducia-nei-vaccini-cala-dove-ce-instabilita-politica-ed-estremismo-religioso-lo-studio/', 'https://nova.ilsole24ore.com/infodata/uno-studente-su-tre-ritiene-che-sarebbe-utile-continuare-a-usare-la-didattica-a-distanza/', 'https://nova.ilsole24ore.com/infodata/che-fine-ha-fatto-il-riscaldamento-climatico-scopri-il-mondo-post-covid-19/', 'https://nova.ilsole24ore.com/infodata/immuni-a-quota-64-milioni-di-download-boom-di-notifiche-con-la-riapertura-della-scuola/', 'https://nova.ilsole24ore.com/infodata/a-proposito-di-dati-le-mappe-catastali-piu-aperte-e-accessibili-basta-citare-la-fonte/', 'https ...

# %%
len(links)
# Out:
# 394

# %%
risultati = []

for link in links:
    PATH = "C:\webdrivers\chromedriver.exe"
    driver = webdriver.Chrome(PATH)

    
    driver.get(link)      
    
    #time.sleep(5)  # fa sonno per 5 secondi

    #cookie = driver.find_element_by_id('onetrust-accept-btn-handler').click() #serve altrimenti prende il p del biscotto

    


    titolo = driver.find_element_by_xpath('.//*[@id="mainbar"]/article/header/h1').text
    elementip = driver.find_elements_by_tag_name("p") #lista intera di tutti gli elementi p

    paragrafi = []
    
    for paragrafo in elementip:
        paragrafi.append(paragrafo.text)
    #print(paragrafi)


    testo = ' '.join(map(str, paragrafi))   # Use map() method for mapping str (for converting elements in list to string) with given iterator, the list.



    art_item = {
        
            'Titolo': titolo,
        
            'Testo': testo
       }
    risultati.append(art_item)

    driver.quit()
    
print(risultati)
    
    
   # RIMASUGLI DEL PROGRAMMA PASSATO    
    
    
    
    #titolo = driver.find_element_by_xpath('.//*[@id="mainbar"]/article/header/h1').text
    #testo = driver.find_element_by_xpath('.//*[@class="article-text"]').text
    #testo = driver.find_element_by_xpath('.//*[@id="mainbar"]/article/div/div/div[2]').text #si blocca a studenti 13% perchè manca un div

    #titolo = driver.find_element_by_xpath('.//header/h1').text
    #testo = driver.find_element_by_xpath('.//*[@id="mainbar"]/article/div/div/div[2]').text
    #titolo = driver.find_element_by_xpath('.//article/header/h1').text
    #testo = driver.find_element_by_xpath('.//*[@class="article-text"]//p').text
    #art_item = {
        #'Link': link,
        #'Titolo': titolo,
        #'Categoria': categoria,
        #'Data_pubblicazione': data_pubblicazione,
        #'Timestamp dello scraping': timestamp,
        #'Testo': testo
   # }
    #resultati.append(art_item)

    
    #time.sleep(2)
    #driver.quit()
    
#print(resultati)
# Out:
# [{'Titolo': 'Il Covid-19 e la seconda ondata (dell’infodemia): diffidate di chi usa i numeri assoluti', 'Testo': '«C’è stato un risveglio. Lo hai percepito?». Il lettore ci consenta di citare il leader supremo Snoke (molto probabilmente uno dei personaggi meno riusciti dell’universo di Star Wars, quasi certamente uno dei meno approfonditi, ndr) per tornare a parlare di come vengono diffusi i dati relativi alla pandemia da nuovo coronavirus. Il risveglio non riguarda tanto l’aumento in numeri assoluti dei contagi registrati nel nostro Paese. Quanto il fatto che sta arrivando la seconda ondata dell’infodemia. E se è sano che ci sia dibattito tra gli scienziati rispetto a un virus del quale ancora resta molto da scoprire, lo è un po’ meno che questo dibattito avvenga in prima serata in Tv. Ed è del tutto controproducente quando finisce in risse, fortunatamente solo verbali, a mezzo social. I superdiffusori dell’infodemia, però, restano i giornalisti (chi scrive non è esente, ndr). E sui giornali, sineddoche entro la quale ci sia permesso di ricomprendere ogni mezzo di informazione, la seconda ondata è ben presente. Certo, il fatto che il presidente americano Donald Trump sia risultato positivo, con le conseguenze che questo può avere in termini geopolitici, non aiuta. Nel senso che contribuisce ad aumentare l’attenzione mediatica sulla pandemia. Fortunatamente, la scienza ha elaborato un tampone che permette di riconoscere la positività a questa patologia. Un tampone del tutto gratuito e che è a disposizione di tutti: basta riconoscere il giornalista che utilizza numeri assoluti per raccontare il contagio. E diffidarne. Vale, ovviamente, anche per la redazione di Infodata. Il problema, per mantenere la metafora in una galassia lontana lontana, è che solo un Sith vive di assoluti. Dove i Sith sono i ‘cattivoni’ della saga ideata da George Lucas. E appunto titolare che sabato 3 ottobre si sono registrati 2.844 positivi, oltretutto aggiungendo che non se ne vedevano così tanti da aprile, rappresenta la via per il lato oscuro dell’informazione. E non soltanto perché, prima relativizzazione possibile, significa che si è positivizzato un italiano ogni 21.183. Che, per inciso, significa che è risultato positivo al test un abitante di Sondrio, non ce ne vogliano i valtellinesi. Ma anche perché il numero di persone positive al Sars-CoV-2 dipende dal numero di quelle che vengono sottoposte ad esame diagnostico. Via, ad un tampone. Nello specifico, il 3 ottobre si è registrato un tampone positivo ogni 41,8 dei 118mila test effettuati. Il 21 aprile i positivi furono 2.729, grosso modo quelli di sabato scorso, mentre i tamponi effettuati poco più di 52mila. Il che porta le persone infette scoperte a una ogni 19 esami. Circostanza che conferma una volta di più quanto siano cambiate le cose in questi mesi: sia in termini di quantità di test che di tipologia delle persone che a questi ultimi vengono sottoposte. Che, più in generale, di andamento della pandemia. Tutti elementi che il numero assoluto dei nuovi positivi non permette di valutare. Così come ha poco senso, al netto del cattivo gusto, pubblicare la classifica dei Paesi con più decessi espressi in numeri assoluti. Specie se si afferma che al terzo posto c’è l’India con 94.503 morti e al sesto l’Italia con 35.835. Peccato che, al 2018, i cittadini indiani fossero 1,353 miliardi, contro i 60,2 milioni di italiani al 1 gennaio di quest’anno. Il che significa che Nuova Delhi ha registrato 1 morto per Covid-19 ogni 14.603 abitanti, mentre Roma uno ogni 1.681. E poi c’è il fattore tempo. Nel senso che quando si cerca di andare oltre il numero assoluto, spesso si tende a commettere l’errore di confrontare la situazione con quella del giorno precedente. E parlare quindi, a seconda dei casi, di tendenza in aumento o in diminuzione. Posto che le tendenze si valutano su periodi più lunghi, i confronti tra giorni successivi rischiano di risentire di diversi fattori di disturbo. Come il fatto che ne ...

# %%
df = pd.DataFrame(risultati)

df.to_csv(r'C:\Users\robeo\Desktop\Soloparte1.csv', index = False, header = True)

print(df)
# Out:
#                                                 Titolo  \
# 0    Il Covid-19 e la seconda ondata (dell’infodemi...
# 1    Elezioni Usa, gli effetti della sorpresa di ot...
# 2    Acqua alta a Venezia, tutti gli eventi eccezio...
# 3    Come si misura la sostenibilità di un investim...
# 4    Il reddito di base universale dal 1960 a oggi ...
# ..                                                 ...
# 389  Cassa integrazione, in aprile autorizzate le s...
# 390  Trapani è caduta: ora è Crotone l’unica provin...
# 391  Turismo alpino e Covid: la montagna è pronta a...
# 392  Comunicare i dati vs illustrare i numeri. Pens...
# 393  Come sta andando il contagio in Umbria? L’indi...
#
#                                                  Testo
# 0    «C’è stato un risveglio. Lo hai percepito?». I...
# 1    Il fatto che un evento sia statisticamente imp...
# 2      Il Mose funziona. L’opera realizzata per dif...
# 3       Vale per un fondo, così come per qualsiasi ...
# 4    ll reddito di base incondizionato o reddito di...
# ..                                                 ...
# 389    Nel solo mese di aprile Inps ha autorizzato ...
# 390      Trapani è caduta. La prima provincia itali...
# 391   Ci si preoccupa, giustamente, di come i nostr...
# 392      A volte è difficile sapere quali statistic...
# 393  Con il nuovo rapporto pubblicato dall’istituto...
#
# [394 rows x 2 columns]
